# %%
import ocsmesh
import pyschism
import pyschism.driver

from pyschism.mesh.base import Elements
from pyschism.mesh.base import Gr3
from pyschism.mesh.gridgr3 import Gr3Field
from pyschism.param.param import Param
import ocsmesh
import pyschism
import pyschism.driver
from cartopy.feature import NaturalEarthFeature
from shapely import geometry, ops
import geopandas as gpd

# %%
mesh_obj3 = ocsmesh.Mesh.open('/contrib/Yunfang.Sun/sunflow/myflow/subset/subset_7.2dm', crs=4326)

# %%
def plot_mesh_edge(msh_t_obj, ax=None, **kwargs):
    crd = msh_t_obj.vert2['coord']
    cnn = msh_t_obj.tria3['index']
    
    if ax == None:
        fig, ax = plt.subplots()
    ax.triplot(crd[:, 0], crd[:, 1], cnn, **kwargs)
    ax.set_aspect(1)
    return ax
    
def plot_mesh_vals(msh_t_obj, ax=None, colorbar=True, clim=None, **kwargs):
    crd = msh_t_obj.vert2['coord']
    cnn = msh_t_obj.tria3['index']
    val = msh_t_obj.value.flatten()
    
    if ax == None:
        fig, ax = plt.subplots()
    mappable = ax.tricontourf(crd[:, 0], crd[:, 1], cnn, val, **kwargs)
    if colorbar:
        if clim is not None:
            mappable.set_clim(*clim)
        cb = plt.colorbar(mappable)

    ax.set_aspect(1)

    return ax

# %%
base_mesh = mesh_obj3
#generate the boundaries of the final grids

base_mesh.boundaries.auto_generate(-10)

roi_box1 = geometry.box(-100, 0, -60.01, 50)
#subset_mesh.boundaries.set_open(box(70, 170, 77, 176), merge=True)
base_mesh.boundaries.set_land(region=roi_box1, merge=True)

roi_box1 = geometry.box(-60.01, 8.6, -59.95, 45.8)

base_mesh.boundaries.set_open(region=roi_box1, merge=True)

#roi_box = geometry.box(-60.25, 8.25, -59.95, 9)

# %%
import matplotlib.pyplot as plt

#base_mesh = mesh_obj3

#ax_tidal_5 = ax

#ax_tidal_5 = gs_region.plot(color='c', alpha=0.8)

fig, ax_tidal_5 = plt.subplots()

plot_mesh_edge(base_mesh.msh_t, ax=ax_tidal_5, lw=0.2, color='c')

base_mesh.boundaries.ocean().plot(ax=ax_tidal_5, color='b', label='Ocean')
base_mesh.boundaries.interior().plot(ax=ax_tidal_5, color='g', label='Islands')
base_mesh.boundaries.land().plot(ax=ax_tidal_5, color='r', label='Land')
plt.legend()

ax_tidal_5.set_aspect(1)
# Out:
# /tmp/ipykernel_14094/4225809359.py:13: DeprecationWarning: This is the old API and will be deprecated in the future release! Use `open()` instead
#   base_mesh.boundaries.ocean().plot(ax=ax_tidal_5, color='b', label='Ocean')

# %%
fig, ax_tidal_5 = plt.subplots()

plot_mesh_edge(base_mesh.msh_t, ax=ax_tidal_5, lw=0.2, color='c')

base_mesh.boundaries.ocean().plot(ax=ax_tidal_5, color='b', label='Ocean')
base_mesh.boundaries.interior().plot(ax=ax_tidal_5, color='g', label='Islands')
base_mesh.boundaries.land().plot(ax=ax_tidal_5, color='r', label='Land')
#plt.legend()

roi_box = geometry.box(-60.5, 7, -59, 48)
ax_tidal_5.set_xlim(roi_box.bounds[0] , roi_box.bounds[2] )
ax_tidal_5.set_ylim(roi_box.bounds[1] , roi_box.bounds[3] )


ax_tidal_5.set_aspect(1)
# Out:
# /tmp/ipykernel_14094/1638924415.py:5: DeprecationWarning: This is the old API and will be deprecated in the future release! Use `open()` instead
#   base_mesh.boundaries.ocean().plot(ax=ax_tidal_5, color='b', label='Ocean')

# %%
fig, ax_tidal_5 = plt.subplots()

plot_mesh_edge(base_mesh.msh_t, ax=ax_tidal_5, lw=0.2, color='c')

base_mesh.boundaries.ocean().plot(ax=ax_tidal_5, color='b', label='Ocean')
base_mesh.boundaries.interior().plot(ax=ax_tidal_5, color='g', label='Islands')
base_mesh.boundaries.land().plot(ax=ax_tidal_5, color='r', label='Land')
#plt.legend()

roi_box = geometry.box(-60.2, 45, -59.95, 46)
ax_tidal_5.set_xlim(roi_box.bounds[0] , roi_box.bounds[2] )
ax_tidal_5.set_ylim(roi_box.bounds[1] , roi_box.bounds[3] )


ax_tidal_5.set_aspect(1)
# Out:
# /tmp/ipykernel_14094/2550641761.py:5: DeprecationWarning: This is the old API and will be deprecated in the future release! Use `open()` instead
#   base_mesh.boundaries.ocean().plot(ax=ax_tidal_5, color='b', label='Ocean')

# %%
fig, ax_tidal_5 = plt.subplots()

plot_mesh_edge(base_mesh.msh_t, ax=ax_tidal_5, lw=0.2, color='c')

base_mesh.boundaries.ocean().plot(ax=ax_tidal_5, color='b', label='Ocean')
base_mesh.boundaries.interior().plot(ax=ax_tidal_5, color='g', label='Islands')
base_mesh.boundaries.land().plot(ax=ax_tidal_5, color='r', label='Land')
#plt.legend()

roi_box = geometry.box(-60.25, 8.25, -59.95, 9)
ax_tidal_5.set_xlim(roi_box.bounds[0] , roi_box.bounds[2] )
ax_tidal_5.set_ylim(roi_box.bounds[1] , roi_box.bounds[3] )


ax_tidal_5.set_aspect(1)
# Out:
# /tmp/ipykernel_14094/933371953.py:5: DeprecationWarning: This is the old API and will be deprecated in the future release! Use `open()` instead
#   base_mesh.boundaries.ocean().plot(ax=ax_tidal_5, color='b', label='Ocean')

# %%
fig, ax_tidal_5 = plt.subplots()

#plot_mesh_edge(base_mesh.msh_t, ax=ax_tidal_5, lw=0.2, color='c')

base_mesh.boundaries.ocean().plot(ax=ax_tidal_5, color='b', label='Ocean')
base_mesh.boundaries.interior().plot(ax=ax_tidal_5, color='g', label='Islands')
#base_mesh.boundaries.land().plot(ax=ax_tidal_5, color='r', label='Land')
#plt.legend()

#ax_tidal_5.set_aspect(1)
# Out:
# /tmp/ipykernel_14094/2177885591.py:5: DeprecationWarning: This is the old API and will be deprecated in the future release! Use `open()` instead
#   base_mesh.boundaries.ocean().plot(ax=ax_tidal_5, color='b', label='Ocean')
# <Axes: >

# %%
#import matplotlib.pyplot as plt

#base_mesh = mesh_obj3

#ax_tidal_5 = ax

#ax_tidal_5 = gs_region.plot(color='c', alpha=0.8)

fig, ax_tidal_5 = plt.subplots()

#plot_mesh_edge(base_mesh.msh_t, ax=ax_tidal_5, lw=0.2, color='c')

base_mesh.boundaries.ocean().plot(ax=ax_tidal_5, color='b', label='Ocean')
base_mesh.boundaries.interior().plot(ax=ax_tidal_5, color='g', label='Islands')
base_mesh.boundaries.land().plot(ax=ax_tidal_5, color='r', label='Land')
plt.legend()

ax_tidal_5.set_aspect(1)
# Out:
# /tmp/ipykernel_14094/892593577.py:13: DeprecationWarning: This is the old API and will be deprecated in the future release! Use `open()` instead
#   base_mesh.boundaries.ocean().plot(ax=ax_tidal_5, color='b', label='Ocean')

# %%
dir(base_mesh.boundaries.land)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__func__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
try:
    size = len(base_mesh.boundaries.land)
    print(f"Size of base_mesh.boundaries.land: {size}")
except TypeError:
    print("base_mesh.boundaries.land does not support len().")
# Out:
# base_mesh.boundaries.land does not support len().

# %%
print(dir(base_mesh.boundaries.land))
# Out:
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__func__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']

# %%
base_mesh.write('/contrib/Yunfang.Sun/sunflow/myflow/subset/subset_corrected/subset7_corr.gr3', format='grd', overwrite=True)
base_mesh.write('/contrib/Yunfang.Sun/sunflow/myflow/subset/subset_corrected/subset7_corr.2dm', format='2dm', overwrite=True)

# %%
import os
from pyschism.forcing.nws import GFS, HRRR, ERA5, BestTrackForcing
from datetime import datetime, timedelta
import pathlib

from pyschism.mesh.base import Elements
from pyschism.mesh.base import Gr3
from pyschism.mesh.gridgr3 import Gr3Field
from pyschism.param.param import Param
import ocsmesh
import pyschism
import pyschism.driver

from __future__ import annotations
from copy import deepcopy
from datetime import datetime, timedelta
from pathlib import Path

#hgrid = pyschism.mesh.Hgrid.open('tidal.schism.pahm.adcirc/ww3_at_sch.gr3', crs=4326)

#hgrid = pyschism.mesh.Hgrid.open('/contrib/Yunfang.Sun/CoastalApp-testsuite/comm/mesh/fort_1.14', crs=4326)

hgrid = pyschism.mesh.Hgrid.open('/contrib/Yunfang.Sun/sunflow/myflow/subset/subset_corrected/subset7.gr3', crs=4326)


dramp = timedelta(days=8.)



atmospheric = BestTrackForcing.from_nhc_bdeck(nhc_bdeck='hurricane-track.dat') 

fgrid = pyschism.mesh.ManningsN.linear_with_depth(
    hgrid,
    min_value=0.02, max_value=0.05,
    min_depth=-1.0, max_depth=-3.0)


config = pyschism.driver.ModelConfig(
    hgrid=hgrid,
    fgrid=fgrid,
#    iettype=pyschism.forcing.bctides.iettype.Iettype3(database="tpxo"),
#    ifltype=pyschism.forcing.bctides.ifltype.Ifltype3(database="tpxo"),

    flags=[[3,3,0,0] for i in hgrid.boundaries.open.itertuples()],
    constituents = 'major',
    database = 'tpxo',
#    nws=atmospheric,
#    nws=NWS2(ERA5()),
    )




coldstart = config.coldstart(
    start_date=datetime(2022,9,15) ,
    end_date=datetime(2022,10,7),       
    timestep=timedelta(seconds=150),
    dramp=dramp,
    dramp_ss=dramp,
    drampwind=dramp,
    nspool=timedelta(hours=1),
    elev=True,
    dahv=True,
    )

coldstart.write(Path('/contrib/Yunfang.Sun/sunflow/myflow/subset/subset_corrected/'), overwrite=True)
# Out:
# /contrib/Yunfang.Sun/conda3/envs/adcirc_subset_schism_dask_new/lib/python3.11/site-packages/stormevents/nhc/track.py:173: UserWarning: It is recommended to specify the file_deck and/or advisories when reading from file
#   warnings.warn(
# Temperature is not sepcified, not input needed!
# ---------------------------------------------------------------------------
# QhullError                                Traceback (most recent call last)
# Cell In[25], line 66
#      38 config = pyschism.driver.ModelConfig(
#      39     hgrid=hgrid,
#      40     fgrid=fgrid,
#    (...)
#      48 #    nws=NWS2(ERA5()),
#      49     )
#      54 coldstart = config.coldstart(
#      55     start_date=datetime(2022,9,15) ,
#      56     end_date=datetime(2022,10,7),
#    (...)
#      63     dahv=True,
#      64     )
# ---> 66 coldstart.write(Path('/contrib/Yunfang.Sun/sunflow/myflow/subset/subset_corrected/'), overwrite=True)
#
# File /contrib/Yunfang.Sun/conda3/envs/adcirc_subset_schism_dask_new/lib/python3.11/site-packages/pyschism/driver.py:384, in ModelDriver.write(self, output_directory, overwrite, hgrid, vgrid, fgrid, param, bctides, nws, stations, use_param_template, albedo, diffmax, diffmin, watertype, windrot, shapiro, fluxflag, tvdflag, elev_ic, temp_ic, salt_ic, hydrology)
#     381 obj_write(elev_ic, self.elev_ic, "elev.ic", overwrite)
#     382 obj_write(stations, self.stations, "station.in", overwrite)
# --> 384 self.config.forcings.write(
#     385     self, output_directory, overwrite,
#     386 )
#     388 MakefileDriver(self.server_config, hotstart=self.hotstart).write(
#     389     self.outdir / "Makefile", overwrite
#     390 )
#
# File /contrib/Yunfang.Sun/conda3/envs/adcirc_subset_schism_dask_new/lib/python3.11/site-packages/pyschism/driver.py:52, in ModelForcings.write(self, driver, output_directory, overwrite)
#      44 def write(
#      45     self,
#      46     driver: "ModelDriver",
#      47     output_directory,
#      48     overwrite,
#      49 ):
#      51     if self.bctides is not None:
# ---> 52         self.bctides.write(
#      53             output_directory,
#      54             start_date=driver.param.opt.start_date,
#      55             rnday=driver.param.core.rnday,
#      56             overwrite=True,
#      57         )
#      59     if self.nws is not None:
#      60         if isinstance(self.nws, NWS2):
#
# File /contrib/Yunfang.Sun/conda3/envs/adcirc_subset_schism_dask_new/lib/python3.11/site-packages/pyschism/forcing/bctides/bctides.py:265, in Bctides.write(self, output_directory, start_date, rnday, overwrite)
#     263     raise IOError("path exists and overwrite is False")
#     264 with open(bctides, "w") as f:
# --> 265     f.write(str(self))
#
# File /contrib/Yunfang.Sun/conda3/envs/adcirc_subset_schism_dask_new/lib/python3.11/site-packages/pyschism/forcing/bctides/bctides.py:162, in Bctides.__str__(self)
#     160 f.append(f"{constituent}")
#     161 vertices = self.hgrid.get_xy(crs=self.hgrid.crs)[boundary.indexes, :]
# --> 162 uamp, uphase, vamp, vphase = self.tides.get_velocity(constituent, vertices)
#     163 for i in range(len(boundary.indexes)):
#     164     f.append(f"{uamp[i]: .6f} {uphase[i]: .6f} {vamp[i]: .6f} {vphase[i]: 6f}")
#
# File /contrib/Yunfang.Sun/conda3/envs/adcirc_subset_schism_dask_new/lib/python3.11/site-packages/pyschism/forcing/bctides/tides.py:160, in Tides.get_velocity(self, constituent, vertices)
#     154     return amps, phases
#     156 # if vertices is None:
#     157     # raise ValueError(
#     158     #     'Argument vertices must not be None for tidal constituent '
#     159     #     f'{constituent}.')
# --> 160 return self.tidal_database.get_velocity(constituent, vertices)
#
# File /contrib/Yunfang.Sun/conda3/envs/adcirc_subset_schism_dask_new/lib/python3.11/site-packages/pyschism/forcing/bctides/tpxo.py:52, in TPXO.get_velocity(self, constituent, vertices)
#      49 def get_velocity(self, constituent, vertices):
#      50     logger.info('Querying TPXO for velocity constituent '
#      51                 f'{constituent}.')
# ---> 52     uamp = self._get_interpolation(
#      53         'velocity', 'ua', constituent, vertices) / 100.
#      54     uphase = self._get_interpolation(
#      55         'velocity', 'up', constituent, vertices)
#      56     vamp = self._get_interpolation(
#      57         'velocity', 'va', constituent, vertices) / 100.
#
# File /contrib/Yunfang.Sun/conda3/envs/adcirc_subset_schism_dask_new/lib/python3.11/site-packages/pyschism/forcing/bctides/tpxo.py:179, in TPXO._get_interpolation(self, phys_var, ncvar, constituent, vertices)
#     165         iidx = np.where(np.logical_and(mask1, mask2))
#     167 #        print("xi1:",xi.shape, xi) #sun01232024
#     168 #        print("yi1:",yi.shape,  yi)
#     169
#    (...)
#     174 #        print("xi[iidx]:",iidx, xi[iidx])
#     175 #        print("yi[iidx]:",iidx, yi[iidx]) #sun01232024
# --> 179         values = griddata(
#     180             (xi[iidx], yi[iidx]),
#     181             zi[iidx],
#     182             (xo, yo),
#     183             method='linear',
#     184             fill_value=np.nan,
#     185         )
#     186         nan_idxs = np.where(np.isnan(values))
#     187         values[nan_idxs] = griddata(
#     188             (xi[iidx], yi[iidx]),
#     189             zi[iidx],
#     190             (xo[nan_idxs], yo[nan_idxs]),
#     191             method='nearest',
#     192         )
#
# File /contrib/Yunfang.Sun/conda3/envs/adcirc_subset_schism_dask_new/lib/python3.11/site-packages/scipy/interpolate/_ndgriddata.py:273, in griddata(points, values, xi, method, fill_value, rescale)
#     271     return ip(xi)
#     272 elif method == 'linear':
# --> 273     ip = LinearNDInterpolator(points, values, fill_value=fill_value,
#     274                               rescale=rescale)
#     275     return ip(xi)
#     276 elif method == 'cubic' and ndim == 2:
#
# File interpnd.pyx:290, in scipy.interpolate.interpnd.LinearNDInterpolator.__init__()
#
# File _qhull.pyx:1827, in scipy.spatial._qhull.Delaunay.__init__()
#
# File _qhull.pyx:353, in scipy.spatial._qhull._Qhull.__init__()
#
# QhullError: QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate 299.4
#
# While executing:  | qhull d Qt Q12 Qbb Qc Qz
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 722362788  delaunay  Qtriangulate  Q12-allow-wide  Qbbound-last
#   Qcoplanar-keep  Qz-infinity-point  _pre-merge  _zero-centrum  Qinterior-keep
#   Pgood  _max-width 0.33  Error-roundoff 4.2e-13  _one-merge 2.9e-12
#   Visible-distance 8.3e-13  U-max-coplanar 8.3e-13  Width-outside 1.7e-12
#   _wide-facet 5e-12  _maxoutside 3.3e-12

# %%
from pyschism.mesh import Hgrid, gridgr3
windrot = gridgr3.Windrot.default(hgrid)
windrot.write('/contrib/Yunfang.Sun/sunflow/myflow/subset/subset_corrected/' + "windrot_geo2proj.gr3", overwrite=True)

# %%
atm_bbox = hgrid.bbox
        
        #sflux_dir = output_directory+"/sflux"
        #os.mkdir(sflux_dir)
        #sflux_dir = os.path.join("r", run_directory, "sflux")
sflux_dir = ('/contrib/Yunfang.Sun/sunflow/myflow/subset/subset_corrected/' + "sflux")
os.makedirs(sflux_dir, exist_ok=True)

era5 = ERA5()
era5.write(
#    outdir=sflux_dir,
    outdir=pathlib.Path(sflux_dir),
    start_date=datetime(2022,9,15),
#    end_date=datetime(2022,10,15), 
    rnday=22,
#    rnday=timedelta(days=30.),
    air=True, rad=True, prc=True,
    bbox=atm_bbox,
    overwrite=True)
